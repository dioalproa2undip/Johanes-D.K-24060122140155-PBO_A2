# %%
#Johanes D.K
#NIM : 24060122140155
#soal no 1 dan 2
import pandas as pd
#import dataset iris
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
#jenis kolom
names =['sepal-width', 'petal-length', 'petal-width', 'class']
dataset = pd.read_csv(url, header=None, names=names)
#code untuk mencetak fitur 2 dan 3
fitur_2_dan_3 = dataset[['sepal-width', 'petal-length']]
print(fitur_2_dan_3.head())
# Out:
#      sepal-width  petal-length
# 5.1          3.5           1.4
# 4.9          3.0           1.4
# 4.7          3.2           1.3
# 4.6          3.1           1.5
# 5.0          3.6           1.4

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
#ambil data iris dan fiturnya
iris = load_iris()
features = iris.data
#ambil fitur 2 dan 3
sepal_width = features[:, 1] #fitur 2
petal_length = features[:, 2] #fitur 3
plt.figure(figsize=(8,6))

plt.scatter(sepal_width, petal_length, c='black', s=7)
plt.colorbar(label='flower class')

SSE =[]
K = range(1,11)
for k in K:
  kmeanModel = KMeans(n_clusters=k)
  kmeanModel.fit(features[:, [1,2]])
  SSE.append(kmeanModel.inertia_)

plt.subplot(1,2,2)
plt.plot(K, SSE, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.tight_layout
plt.show()

# %%
y_pred = KMeans(n_clusters=3).fit_predict(features)
plt.plot
LABEL_COLOR_MAP = {0:'r', 1:'g', 2:'b'}
label_color = [LABEL_COLOR_MAP[l] for l in y_pred]
plt.scatter(features[:, 1], features[:, 2], c=y_pred)
plt.show()
